# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:29, 1.06MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
freqs = np.zeros(len(int_to_vocab))
for w in int_words:
    freqs[w] += 1.0
freqs /= len(int_words)

header = "{:5} {:10} {:11}".format("rank", "word", "freq")
print(header)
print('-'*len(header))
for i in range(0,1000,50):
    v = int_to_vocab[i]
    f = freqs[i]
    print("{:5} {:10} {:0.9f}".format(i,v,f))

keep = [r>(1 - np.sqrt(1e-5/freqs[w])) for w,r in zip(int_words, np.random.uniform(size=len(int_words)))]
train_words = [w for w,k in zip(int_words, keep) if k]
# Out:
# rank  word       freq
# ----------------------------
#     0 the        0.063630569
#    50 more       0.001572066
#   100 city       0.000735885
#   150 french     0.000523722
#   200 political  0.000417851
#   250 us         0.000338837
#   300 according  0.000292795
#   350 service    0.000255387
#   400 culture    0.000228349
#   450 ancient    0.000211203
#   500 latin      0.000197235
#   550 won        0.000179190
#   600 education  0.000165402
#   650 outside    0.000154311
#   700 cause      0.000143400
#   750 greater    0.000134827
#   800 cell       0.000126794
#   850 attempt    0.000121878
#   900 replaced   0.000116363
#   950 entire     0.000111866

# %%
start = 1000
length = 100

print('Original')
print('--------')
print(' '.join(w for w in words[start:start+length]))
print('Discarded')
print('--------')
print(' '.join(w if k else 'x'*len(w) for w,k in zip(words[start:start+length], keep[start:start+length])))
# Out:
# Original
# --------
# eight two five josiah warren had participated in a communitarian experiment headed by robert owen called new harmony which failed in a few years amidst much internal conflict warren blamed the community s failure on a lack of individual sovereignty and a lack of private property warren proceeded to organise anarchist communities which respected what he called the sovereignty of the individual at utopia and modern times in one eight three three warren wrote and published the peaceful which some have noted to be the first anarchist periodical ever published benjamin tucker says that warren was the first man to
# Discarded
# --------
# xxxxx xxx xxxx josiah warren xxx xxxxxxxxxxxx xx x communitarian xxxxxxxxxx xxxxxx by robert owen xxxxxx xxx xxxxxxx xxxxx failed xx x xxx xxxxx amidst much xxxxxxxx xxxxxxxx warren blamed xxx xxxxxxxxx x xxxxxxx xx x xxxx xx xxxxxxxxxx sovereignty xxx x xxxx xx private xxxxxxxx warren proceeded xx organise anarchist communities xxxxx respected xxxx xx xxxxxx xxx xxxxxxxxxxx xx the xxxxxxxxxx xx utopia xxx modern xxxxx xx xxx xxxxx xxxxx xxxxx warren xxxxx xxx xxxxxxxxx xxx peaceful xxxxx some xxxx xxxxx xx xx xxx xxxxx anarchist periodical xxxx xxxxxxxxx xxxxxxxx tucker says xxxx warren xxx xxx xxxxx xxx xx

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    w = np.random.randint(window_size+1)
    return words[max(0,idx-w):idx] + words[idx+1:min(len(words)-1, idx+w+1)]

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, shape=(None))
    labels = tf.placeholder(tf.int32, shape=(None, 1))

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform(shape=(n_vocab, n_embedding), minval=-1, maxval=1))
    # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs)# use tf.nn.embedding_lookup to get the hidden layer output

# %%
#sess = tf.InteractiveSession()
#params = tf.constant(np.eye(4))
#ids = tf.constant([0,1,2,2])
#print(tf.nn.embedding_lookup(params,ids).eval())

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal(shape=(n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(shape=n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
import random

with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6210 0.2182 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5613 0.2114 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4687 0.2098 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5510 0.2112 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4442 0.2118 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5070 0.2108 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5144 0.2109 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5296 0.2103 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4536 0.2086 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.3857 0.2079 sec/batch
# Nearest to four: alias, defections, od, tanna, integumentary, hindering, turquoise, numerically,
# Nearest to also: stationing, seminaries, gundahar, oldest, namath, kigamboni, keg, symbolizes,
# Nearest to other: prostaglandin, caduceus, poset, grievous, salina, readily, nestorius, colonizer,
# Nearest to is: damping, allahabad, lobbyist, chorales, avicenna, ephesus, autumnal, probabilistic,
# Nearest to called: degrade, luxuries, beth, gnasher, suo, transcendental, setter, disabilities,
# Nearest to american: filenames, asymptotically, reestablished, philologist, ruthenia, nathalie, stubs, explicate,
# Nearest to seven: pancho, relena, supremum, avms, rem, moral, iso, principally,
# Nearest to more: bir, restaurant, rebels, chopper, doubling, collate, bo, coaster,
# Nearest to rise: hanun, ssang, uel, mimic, nixon, cagney, antrim, compasses,
# Nearest to existence: andreini, hine, intellectual, beasts, tegea, therus, christophe, projects,
# Nearest to shown: tuna, bad, abhidharma, cahokia, bathtub, republica, limbo, masuria,
# Nearest to http: reprint, contractile, reger, quest, hangzhou, undefended, muses, deacidification,
# Nearest to except: stench, honeymoon, macintosh, kenneth, mutagens, identified, debuted, shanks,
# Nearest to pope: ancus, cryoprotectant, firestorm, suu, godhead, lathe, functioned, unicorn,
# Nearest to event: astronautica, amines, papal, economists, novel, martin, anything, consanguinity,
# Nearest to active: volcanoes, australasia, sustains, cap, mmorpgs, beavis, jarmusch, antiochus,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4783 0.2090 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3635 0.2059 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3479 0.2052 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2414 0.2050 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2076 0.2046 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.2062 0.2136 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1336 0.2074 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.1130 0.2443 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0363 0.2154 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0447 0.2070 sec/batch
# Nearest to four: alias, alter, defections, approach, traced, tanna, turquoise, member,
# Nearest to also: oldest, keg, economies, name, stationing, object, seminaries, deficiency,
# Nearest to other: readily, interpretation, prostaglandin, determines, caduceus, poset, beef, gain,
# Nearest to is: damping, innovations, expression, perry, lobbyist, fold, involves, avicenna,
# Nearest to called: degrade, dvd, explained, homes, luxuries, disabilities, beth, absence,
# Nearest to american: filenames, reestablished, keynes, terrorist, infancy, explicate, asymptotically, spee,
# Nearest to seven: pancho, moral, iso, principally, supremum, avms, smoke, europe,
# Nearest to more: bir, generally, restaurant, rebels, prepare, miners, doubling, tough,
# Nearest to rise: hanun, mimic, antrim, uel, compasses, various, laughed, nixon,
# Nearest to existence: andreini, intellectual, beasts, projects, into, hine, therus, tegea,
# Nearest to shown: bad, tuna, giant, limbo, investigations, bathtub, cahokia, vilhelm,
# Nearest to http: reprint, quest, reger, contractile, muses, hangzhou, undefended, governing,
# Nearest to except: stench, identified, kenneth, honeymoon, mutagens, macintosh, engaged, marcius,
# Nearest to pope: ancus, firestorm, cryoprotectant, write, functioned, godhead, motion, monarchs,
# Nearest to event: astronautica, novel, anything, papal, economists, them, martin, amines,
# Nearest to active: volcanoes, best, instantly, uniform, tagline, sustains, antiochus, mmorpgs,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9651 0.2091 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9210 0.2081 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8882 0.2076 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8917 0.2073 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8301 0.2057 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8412 0.2216 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8043 0.2180 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8148 0.2256 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8117 0.2261 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7995 0.2151 sec/batch
# Nearest to four: alias, denied, szil, alter, moderate, tanna, revive, convened,
# Nearest to also: oldest, stationing, instructions, motion, economies, symbolizes, seminaries, keg,
# Nearest to other: readily, interpretation, videotape, prostaglandin, determines, caduceus, poset, pursued,
# Nearest to is: damping, perry, incompatible, emblems, susceptible, dependent, entirely, innovations,
# Nearest to called: degrade, disabilities, luxuries, explained, dvd, transcendental, homes, beth,
# Nearest to american: filenames, servants, reestablished, keynes, philologist, asymptotically, infancy, storing,
# Nearest to seven: pancho, relena, moral, dumas, iso, smoke, earl, principally,
# Nearest to more: bir, restaurant, prepare, generally, doubling, idiom, miners, courses,
# Nearest to rise: hanun, mimic, nixon, antrim, compasses, uel, various, exhibits,
# Nearest to existence: intellectual, beasts, andreini, tegea, hine, projects, vernacular, therus,
# Nearest to shown: bad, revenues, tuna, limbo, investigations, giant, bathtub, kuhn,
# Nearest to http: reprint, quest, reger, contractile, com, html, muses, governing,
# Nearest to except: stench, identified, kenneth, honeymoon, debuted, macintosh, mutagens, coincidentally,
# Nearest to pope: ancus, functioned, monarchs, godhead, firestorm, unicorn, write, motion,
# Nearest to event: astronautica, papal, novel, anything, martin, economists, them, coined,
# Nearest to active: volcanoes, best, instantly, mmorpgs, sustains, tagline, antiochus, highest,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.8022 0.2303 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7610 0.2133 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7275 0.2255 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7149 0.2203 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7631 0.2142 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7170 0.2290 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7219 0.2211 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7436 0.2220 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6954 0.2141 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6874 0.2228 sec/batch
# Nearest to four: one, alias, nine, denied, tanna, seven, playoffs, szil,
# Nearest to also: oldest, seminaries, instructions, symbolizes, stationing, economies, keg, outlaw,
# Nearest to other: readily, videotape, prostaglandin, poset, salina, interpretation, deference, grievous,
# Nearest to is: perry, damping, emblems, susceptible, eddy, allahabad, probabilistic, dependent,
# Nearest to called: degrade, disabilities, transcendental, luxuries, dvd, beth, explained, angle,
# Nearest to american: filenames, philologist, keynes, reestablished, boris, servants, gilbert, tig,
# Nearest to seven: pancho, dumas, relena, earl, four, architect, nine, eight,
# Nearest to more: bir, restaurant, generally, prepare, idiom, doubling, putnam, characterizes,
# Nearest to rise: hanun, mimic, uel, exhibits, nixon, antrim, warsaw, compasses,
# Nearest to existence: beasts, intellectual, andreini, vernacular, hine, tegea, drafting, therus,
# Nearest to shown: bad, limbo, tuna, bathtub, revenues, kuhn, investigations, republica,
# Nearest to http: reprint, reger, quest, com, html, contractile, lindisfarne, hangzhou,
# Nearest to except: stench, kenneth, honeymoon, identified, macintosh, mutagens, debuted, coincidentally,
# Nearest to pope: ancus, functioned, firestorm, godhead, monarchs, unicorn, rhineland, cravings,
# Nearest to event: astronautica, papal, anything, martin, novel, untold, economists, them,
# Nearest to active: volcanoes, best, mmorpgs, antiochus, alderman, instantly, disenchanted, australasia,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6961 0.2244 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6852 0.2130 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6261 0.2240 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6296 0.2260 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6376 0.2241 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6697 0.2226 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6048 0.1713 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5888 0.2241 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5370 0.2225 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4925 0.2316 sec/batch
# Nearest to four: one, nine, seven, two, alias, playoffs, tanna, outlaw,
# Nearest to also: oldest, instructions, namath, seminaries, deficiency, krakatoa, yosef, stationing,
# Nearest to other: readily, grievous, poset, videotape, prostaglandin, deference, ultrafilter, salina,
# Nearest to is: damping, emblems, susceptible, probabilistic, expression, eddy, dependent, perry,
# Nearest to called: degrade, transcendental, disabilities, dvd, almoravids, beth, luxuries, angle,
# Nearest to american: philologist, actress, boris, keynes, actor, laureate, gilbert, writer,
# Nearest to seven: earl, pancho, nine, architect, dumas, eight, four, relena,
# Nearest to more: bir, restaurant, corrupting, idiom, generally, coaster, doubling, chopper,
# Nearest to rise: hanun, uel, mimic, beholden, exhibits, compasses, meaninglessness, antrim,
# Nearest to existence: beasts, intellectual, andreini, hine, vernacular, tegea, gamaliel, proposes,
# Nearest to shown: bad, tuna, masuria, limbo, bathtub, paraphyletic, responsive, republica,
# Nearest to http: com, reprint, reger, quest, html, hangzhou, contractile, www,
# Nearest to except: stench, macintosh, identified, honeymoon, kenneth, mutagens, debuted, echoing,
# Nearest to pope: ancus, monarchs, rhineland, godhead, firestorm, functioned, unicorn, cravings,
# Nearest to event: astronautica, anything, papal, economists, amines, untold, nature, novel,
# Nearest to active: volcanoes, best, antiochus, mmorpgs, banco, alderman, australasia, tagline,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5095 0.2248 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5207 0.2186 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4819 0.2172 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5763 0.2246 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5062 0.2153 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4725 0.2168 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4524 0.2077 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4159 0.2268 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4792 0.2227 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4179 0.2174 sec/batch
# Nearest to four: one, two, playoffs, seven, tanna, alias, nine, pancho,
# Nearest to also: oldest, instructions, namath, stationing, krakatoa, yosef, hovering, seminaries,
# Nearest to other: poset, prostaglandin, readily, deference, colonizer, grievous, videotape, ultrafilter,
# Nearest to is: emblems, expression, probabilistic, damping, susceptible, eddy, dependent, axis,
# Nearest to called: degrade, disabilities, transcendental, dvd, angle, beth, almoravids, circle,
# Nearest to american: philologist, filenames, boris, keynes, fomorians, actress, gilbert, actor,
# Nearest to seven: pancho, four, relena, earl, architect, dumas, eight, iso,
# Nearest to more: bir, generally, corrupting, idiom, prepare, restaurant, doubling, chopper,
# Nearest to rise: hanun, uel, beholden, mimic, exhibits, antrim, compasses, meaninglessness,
# Nearest to existence: intellectual, beasts, hine, vernacular, occupational, andreini, gamaliel, proposes,
# Nearest to shown: bad, limbo, bathtub, tuna, masuria, paraphyletic, chords, responsive,
# Nearest to http: com, www, html, reger, reprint, quest, hangzhou, undefended,
# Nearest to except: stench, identified, mutagens, echoing, honeymoon, macintosh, shanks, kenneth,
# Nearest to pope: ancus, monarchs, bishop, rhineland, functioned, godhead, firestorm, cravings,
# Nearest to event: astronautica, anything, papal, nature, untold, economists, amines, martin,
# Nearest to active: volcanoes, mmorpgs, antiochus, best, banco, latterly, alderman, deceptively,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4464 0.2264 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4024 0.2258 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4446 0.2281 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4052 0.2119 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3886 0.2237 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4286 0.2196 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3847 0.2209 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3489 0.2094 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.3950 0.2167 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3661 0.2194 sec/batch
# Nearest to four: one, two, seven, nine, playoffs, tanna, alias, pancho,
# Nearest to also: oldest, namath, krakatoa, instructions, yosef, seminaries, hovering, stationing,
# Nearest to other: poset, prostaglandin, readily, ultrafilter, deference, enthroned, grievous, videotape,
# Nearest to is: expression, axis, emblems, damping, susceptible, probabilistic, coordinate, dependent,
# Nearest to called: degrade, disabilities, transcendental, angle, dvd, circle, angled, almoravids,
# Nearest to american: boris, filenames, actress, philologist, actor, keynes, shaughnessy, spee,
# Nearest to seven: pancho, four, eight, architect, five, earl, relena, iso,
# Nearest to more: bir, generally, corrupting, prepare, restaurant, coaster, idiom, interceptor,
# Nearest to rise: uel, hanun, beholden, exhibits, mimic, compasses, antrim, divest,
# Nearest to existence: beasts, intellectual, vernacular, meaningful, hine, proposes, found, gamaliel,
# Nearest to shown: limbo, bathtub, bad, masuria, tuna, paraphyletic, carpathian, responsive,
# Nearest to http: com, html, www, reprint, reger, quest, hangzhou, undefended,
# Nearest to except: identified, stench, mutagens, shanks, honeymoon, macintosh, coincidentally, echoing,
# Nearest to pope: ancus, monarchs, bishop, godhead, rhineland, functioned, firestorm, philip,
# Nearest to event: astronautica, anything, nature, papal, them, distributism, coined, martin,
# Nearest to active: volcanoes, mmorpgs, banco, alderman, antiochus, latterly, skopje, best,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3935 0.2059 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3554 0.2058 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3411 0.2023 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3598 0.2027 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4017 0.2020 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3862 0.2048 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3784 0.2233 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3616 0.2169 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3321 0.2182 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3565 0.2384 sec/batch
# Nearest to four: one, two, seven, nine, playoffs, alias, zero, tanna,
# Nearest to also: oldest, hovering, krakatoa, namath, stationing, object, tishri, seminaries,
# Nearest to other: ultrafilter, deference, prostaglandin, readily, poset, videotape, interpretation, enthroned,
# Nearest to is: damping, expression, probabilistic, susceptible, coordinate, dependent, resultant, axis,
# Nearest to called: degrade, transcendental, disabilities, almoravids, beth, circle, luxuries, dvd,
# Nearest to american: filenames, boris, spee, actor, shaughnessy, gilbert, actress, philologist,
# Nearest to seven: four, pancho, eight, five, zero, iso, six, nine,
# Nearest to more: bir, prepare, coaster, corrupting, interceptor, idiom, generally, restaurant,
# Nearest to rise: hanun, beholden, uel, exhibits, compasses, divest, mimic, into,
# Nearest to existence: intellectual, beasts, vernacular, hine, proposes, meaningful, concept, found,
# Nearest to shown: limbo, masuria, bathtub, paraphyletic, carpathian, tuna, kuhn, abhidharma,
# Nearest to http: com, html, www, reprint, reger, quest, hangzhou, tp,
# Nearest to except: identified, stench, echoing, mutagens, shanks, macintosh, popperian, coincidentally,
# Nearest to pope: bishop, monarchs, ancus, godhead, functioned, protestantism, rhineland, viii,
# Nearest to event: astronautica, anything, papal, distributism, nature, coined, martin, them,
# Nearest to active: volcanoes, mmorpgs, banco, phishing, alderman, disenchanted, skopje, australasia,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3283 0.2341 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3085 0.2146 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3975 0.2141 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3866 0.2209 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3763 0.2209 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2908 0.2241 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3161 0.2274 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3531 0.2238 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2440 0.2164 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2835 0.2180 sec/batch
# Nearest to four: one, two, seven, nine, playoffs, zero, freiburg, tanna,
# Nearest to also: oldest, stationing, hovering, krakatoa, tishri, yosef, namath, object,
# Nearest to other: deference, prostaglandin, ultrafilter, readily, poset, enthroned, interpretation, sterilisation,
# Nearest to is: damping, expression, chorales, dependent, resultant, coordinate, autumnal, probabilistic,
# Nearest to called: degrade, transcendental, almoravids, disabilities, angle, angled, circle, beth,
# Nearest to american: actor, actress, boris, philologist, songwriter, gilbert, shaughnessy, laureate,
# Nearest to seven: eight, four, zero, five, six, pancho, nine, architect,
# Nearest to more: bir, coaster, corrupting, interceptor, prepare, kinetochores, generally, flexibility,
# Nearest to rise: hanun, beholden, uel, exhibits, divest, antrim, into, mimic,
# Nearest to existence: intellectual, beasts, vernacular, meaningful, concept, hine, proposes, gamaliel,
# Nearest to shown: limbo, bathtub, masuria, tuna, kuhn, carpathian, abhidharma, bad,
# Nearest to http: com, html, www, reprint, reger, htm, quest, tp,
# Nearest to except: stench, identified, mutagens, echoing, internecine, shanks, coincidentally, boredom,
# Nearest to pope: bishop, ancus, monarchs, rhineland, functioned, godhead, philip, protestantism,
# Nearest to event: astronautica, anything, distributism, papal, untold, martin, nature, them,
# Nearest to active: volcanoes, mmorpgs, skopje, disenchanted, banco, phishing, honorum, deceptively,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3104 0.2328 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3003 0.2211 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3379 0.1084 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2519 0.2307 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2202 0.2109 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2111 0.2161 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2106 0.2389 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1953 0.2387 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2052 0.2502 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1556 0.2446 sec/batch
# Nearest to four: one, two, seven, nine, playoffs, zero, freiburg, est,
# Nearest to also: oldest, stationing, yosef, namath, tishri, krakatoa, seminaries, oper,
# Nearest to other: prostaglandin, deference, ultrafilter, enthroned, readily, colonizer, poset, columbian,
# Nearest to is: damping, chorales, autumnal, expression, dependent, resultant, allahabad, cultures,
# Nearest to called: degrade, angle, transcendental, almoravids, disabilities, circle, beth, angled,
# Nearest to american: shaughnessy, actor, filenames, boris, actress, songwriter, philologist, gelli,
# Nearest to seven: five, eight, four, six, zero, pancho, iso, nine,
# Nearest to more: bir, coaster, corrupting, prepare, interceptor, bacteriophage, kinetochores, chopper,
# Nearest to rise: hanun, beholden, uel, exhibits, divest, unrecognized, antrim, compasses,
# Nearest to existence: intellectual, beasts, vernacular, meaningful, concept, proposes, hine, occupational,
# Nearest to shown: limbo, bathtub, paraphyletic, carpathian, masuria, tuna, bad, kuhn,
# Nearest to http: com, www, html, reprint, reger, htm, quest, gov,
# Nearest to except: identified, stench, echoing, mutagens, shanks, boredom, coincidentally, oxfam,
# Nearest to pope: ancus, bishop, monarchs, severus, iv, viii, rhineland, protestantism,
# Nearest to event: astronautica, anything, distributism, untold, papal, martin, cuticle, mastodon,
# Nearest to active: volcanoes, mmorpgs, phishing, skopje, disenchanted, banco, deceptively, etat,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2554 0.2461 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2024 0.2362 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2102 0.2313 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1171 0.2378 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1779 0.2319 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1387 0.2426 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1430 0.2398 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1326 0.2191 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1864 0.2337 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1857 0.2331 sec/batch
# Nearest to four: one, two, nine, seven, zero, playoffs, est, freiburg,
# Nearest to also: oldest, yosef, hovering, kaf, oper, tishri, stationing, kann,
# Nearest to other: prostaglandin, deference, ultrafilter, enthroned, poset, sterilisation, readily, differently,
# Nearest to is: damping, expression, chorales, susceptible, therefore, probabilistic, resultant, coordinate,
# Nearest to called: degrade, angle, circle, transcendental, almoravids, beth, disabilities, absence,
# Nearest to american: filenames, shaughnessy, gelli, boris, folketing, nathalie, spee, actor,
# Nearest to seven: five, six, eight, zero, four, pancho, iso, chandelier,
# Nearest to more: bir, coaster, corrupting, prepare, interceptor, kinetochores, ethnocentric, bacteriophage,
# Nearest to rise: beholden, hanun, uel, exhibits, compasses, divest, into, unrecognized,
# Nearest to existence: beasts, intellectual, vernacular, meaningful, concept, proposes, hine, gamaliel,
# Nearest to shown: limbo, paraphyletic, bathtub, bad, carpathian, kuhn, tuna, masuria,
# Nearest to http: www, com, html, htm, reprint, reger, gov, quest,
# Nearest to except: stench, identified, mutagens, boredom, shanks, oxfam, echoing, coincidentally,
# Nearest to pope: ancus, bishop, severus, godhead, viii, monarchs, popes, ecclesiastical,
# Nearest to event: astronautica, anything, distributism, intruding, cuticle, untold, papal, nature,
# Nearest to active: volcanoes, mmorpgs, disenchanted, skopje, phishing, banco, etat, recreational,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1445 0.2460 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.1869 0.2317 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1746 0.2213 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1206 0.2228 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1826 0.2450 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1677 0.2379 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1727 0.2464 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1331 0.2405 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1114 0.2392 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1682 0.2390 sec/batch
# Nearest to four: one, two, nine, seven, zero, est, freiburg, playoffs,
# Nearest to also: oldest, hovering, yosef, kaf, oper, tishri, groupoid, including,
# Nearest to other: prostaglandin, ultrafilter, deference, enthroned, poset, readily, wide, sterilisation,
# Nearest to is: damping, therefore, coordinate, morphism, expression, unachievable, chorales, susceptible,
# Nearest to called: degrade, circle, angle, beth, transcendental, almoravids, angled, familial,
# Nearest to american: shaughnessy, filenames, actor, boris, spee, gelli, nathalie, actress,
# Nearest to seven: six, zero, four, eight, five, iso, nine, pancho,
# Nearest to more: bir, coaster, corrupting, prepare, ethnocentric, interceptor, kinetochores, bacteriophage,
# Nearest to rise: beholden, uel, hanun, exhibits, unrecognized, economic, abydos, compasses,
# Nearest to existence: meaningful, vernacular, beasts, intellectual, hine, concept, gamaliel, preserve,
# Nearest to shown: limbo, paraphyletic, bathtub, tuna, carpathian, masuria, genomics, bagpuss,
# Nearest to http: com, html, www, htm, gov, edu, reger, reprint,
# Nearest to except: stench, identified, mutagens, coincidentally, echoing, shanks, boredom, oxfam,
# Nearest to pope: ancus, bishop, severus, godhead, popes, monarchs, functioned, antioch,
# Nearest to event: astronautica, intruding, anything, distributism, cuticle, quirks, nature, mastodon,
# Nearest to active: volcanoes, mmorpgs, skopje, phishing, banco, disenchanted, deceptively, librarianship,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1903 0.2533 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1683 0.2232 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1548 0.2347 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1616 0.2362 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1380 0.2153 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1013 0.2154 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1505 0.2385 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1211 0.2330 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1902 0.2355 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2144 0.2281 sec/batch
# Nearest to four: one, two, seven, nine, zero, six, freiburg, three,
# Nearest to also: hovering, oldest, oper, stationing, yosef, kaf, tishri, kann,
# Nearest to other: deference, prostaglandin, ultrafilter, sterilisation, differently, enthroned, theologically, wide,
# Nearest to is: damping, allahabad, perry, chorales, morphism, haereses, coordinate, savagely,
# Nearest to called: beth, almoravids, disabilities, transcendental, philistines, angle, degrade, circle,
# Nearest to american: actor, shaughnessy, boris, actress, filenames, aviator, nathalie, songwriter,
# Nearest to seven: eight, six, zero, five, four, nine, one, pancho,
# Nearest to more: bir, coaster, corrupting, prepare, interceptor, ethnocentric, bacteriophage, kinetochores,
# Nearest to rise: beholden, hanun, uel, exhibits, unrecognized, economic, abydos, antrim,
# Nearest to existence: beasts, vernacular, intellectual, meaningful, hine, concept, gamaliel, andreini,
# Nearest to shown: limbo, bathtub, paraphyletic, carpathian, tuna, bagpuss, kuhn, bad,
# Nearest to http: www, html, com, htm, gov, edu, reger, reprint,
# Nearest to except: stench, identified, mutagens, boredom, shanks, oxfam, coincidentally, echoing,
# Nearest to pope: ancus, bishop, severus, godhead, functioned, popes, viii, monarchs,
# Nearest to event: astronautica, intruding, distributism, anything, nonetheless, cuticle, papal, nature,
# Nearest to active: volcanoes, skopje, mmorpgs, disenchanted, phishing, banco, recreational, librarianship,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2074 0.2294 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1187 0.2348 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1057 0.2330 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.0961 0.2383 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0313 0.2305 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1486 0.2273 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1240 0.2173 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1236 0.2336 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1692 0.0458 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0806 0.2402 sec/batch
# Nearest to four: one, two, seven, nine, zero, six, hdi, est,
# Nearest to also: oper, hovering, oldest, stationing, yosef, including, maya, tishri,
# Nearest to other: prostaglandin, ultrafilter, deference, differently, poset, wide, sterilisation, databases,
# Nearest to is: damping, morphism, of, perry, expression, chorales, coordinate, allahabad,
# Nearest to called: angle, degrade, beth, transcendental, almoravids, circle, associativity, absence,
# Nearest to american: shaughnessy, actor, filenames, nathalie, canadian, gelli, aviator, sparrows,
# Nearest to seven: six, zero, eight, four, five, nine, one, iso,
# Nearest to more: bir, corrupting, coaster, interceptor, industrial, prepare, flexibility, ethnocentric,
# Nearest to rise: beholden, hanun, uel, exhibits, unrecognized, economic, authoritarian, abydos,
# Nearest to existence: beasts, vernacular, meaningful, intellectual, hine, concept, grendel, tegea,
# Nearest to shown: limbo, bathtub, paraphyletic, tuna, carpathian, bagpuss, kuhn, theatre,
# Nearest to http: www, html, com, htm, gov, edu, reger, external,
# Nearest to except: identified, stench, oxfam, boredom, shanks, mutagens, echoing, parastatal,
# Nearest to pope: ancus, bishop, severus, functioned, viii, godhead, popes, moroni,
# Nearest to event: astronautica, distributism, intruding, anything, untold, martin, aloft, pickets,
# Nearest to active: volcanoes, skopje, mmorpgs, phishing, disenchanted, banco, librarianship, deceptively,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0667 0.2400 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0509 0.2290 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0572 0.2040 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0376 0.2036 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0594 0.2031 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0021 0.2032 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0647 0.2029 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0627 0.2027 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.0963 0.2025 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 3.9807 0.2030 sec/batch
# Nearest to four: one, two, seven, nine, zero, six, hdi, three,
# Nearest to also: hovering, oper, oldest, yosef, including, kann, groupoid, stationing,
# Nearest to other: prostaglandin, deference, ultrafilter, differently, theologically, sterilisation, enthroned, readily,
# Nearest to is: damping, morphism, autumnal, unachievable, of, resultant, therefore, opioid,
# Nearest to called: angle, beth, degrade, transcendental, circle, almoravids, angled, subgroups,
# Nearest to american: shaughnessy, filenames, actor, sparrows, nathalie, folketing, gelli, canadian,
# Nearest to seven: six, zero, four, five, eight, nine, one, iso,
# Nearest to more: bir, corrupting, coaster, interceptor, prepare, flexibility, bacteriophage, ethnocentric,
# Nearest to rise: hanun, beholden, uel, exhibits, unrecognized, hebrews, economic, orie,
# Nearest to existence: meaningful, beasts, hine, intellectual, vernacular, idealist, occupational, holism,
# Nearest to shown: limbo, bathtub, paraphyletic, carpathian, tuna, theatre, bad, bivalent,
# Nearest to http: www, html, com, htm, gov, edu, geocities, asp,
# Nearest to except: identified, oxfam, stench, parastatal, praetorian, shanks, boredom, echoing,
# Nearest to pope: ancus, severus, viii, popes, bishop, moroni, iv, functioned,
# Nearest to event: astronautica, distributism, intruding, untold, mastodon, pickets, aloft, silently,
# Nearest to active: volcanoes, skopje, mmorpgs, phishing, disenchanted, librarianship, deceptively, australasia,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.9844 0.2054 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0092 0.2023 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9735 0.2021 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0392 0.2020 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0450 0.2025 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0223 0.2032 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0443 0.2106 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0681 0.1932 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0172 0.1892 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0370 0.1894 sec/batch
# Nearest to four: one, two, nine, seven, zero, six, three, hdi,
# Nearest to also: hovering, oper, including, yosef, kann, oldest, photosynthetic, kaf,
# Nearest to other: prostaglandin, differently, deference, sterilisation, ultrafilter, resilient, correspondences, theologically,
# Nearest to is: damping, unachievable, morphism, therefore, of, coordinate, expression, ung,
# Nearest to called: angle, transcendental, beth, degrade, circle, associativity, subgroups, angled,
# Nearest to american: filenames, shaughnessy, nathalie, actor, gelli, sparrows, candace, race,
# Nearest to seven: six, eight, five, zero, four, nine, one, iso,
# Nearest to more: bir, corrupting, coaster, prepare, ethnocentric, flexibility, bacteriophage, industrial,
# Nearest to rise: beholden, uel, hanun, exhibits, unrecognized, economic, authoritarian, hebrews,
# Nearest to existence: meaningful, beasts, hine, vernacular, intellectual, idealist, holism, minis,
# Nearest to shown: limbo, bathtub, paraphyletic, tuna, bagpuss, carpathian, theatre, hardness,
# Nearest to http: www, html, com, htm, gov, edu, geocities, reger,
# Nearest to except: identified, oxfam, boredom, stench, praetorian, shanks, parastatal, mutagens,
# Nearest to pope: ancus, severus, functioned, bishop, viii, popes, godhead, moroni,
# Nearest to event: astronautica, intruding, distributism, aloft, mastodon, untold, pickets, printout,
# Nearest to active: volcanoes, skopje, phishing, mmorpgs, librarianship, disenchanted, banco, liga,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0162 0.1925 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0456 0.1899 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0436 0.1888 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0297 0.1890 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0413 0.1889 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0195 0.1891 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0534 0.1888 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0263 0.1898 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0618 0.1890 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0590 0.1894 sec/batch
# Nearest to four: one, two, nine, zero, seven, three, six, five,
# Nearest to also: hovering, oper, yosef, including, oldest, kann, photosynthetic, tishri,
# Nearest to other: prostaglandin, differently, deference, ultrafilter, theologically, vocalization, sterilisation, rhyming,
# Nearest to is: damping, morphism, ung, unachievable, perry, of, therefore, allahabad,
# Nearest to called: angle, beth, transcendental, almoravids, familial, philistines, circle, degrade,
# Nearest to american: shaughnessy, filenames, actor, nathalie, spee, gelli, sparrows, francks,
# Nearest to seven: six, zero, eight, five, four, nine, one, iso,
# Nearest to more: bir, corrupting, ethnocentric, coaster, prepare, bacteriophage, industrial, sushi,
# Nearest to rise: beholden, uel, hanun, authoritarian, economic, exhibits, unrecognized, abydos,
# Nearest to existence: beasts, hine, grendel, idealist, vernacular, meaningful, holism, tegea,
# Nearest to shown: limbo, bathtub, paraphyletic, tuna, carpathian, bagpuss, theatre, bivalent,
# Nearest to http: www, html, com, htm, gov, edu, geocities, reger,
# Nearest to except: identified, praetorian, stench, oxfam, shanks, boredom, mutagens, apostolic,
# Nearest to pope: ancus, viii, severus, bishop, popes, functioned, moroni, godhead,
# Nearest to event: distributism, intruding, astronautica, aloft, untold, mastodon, martin, pickets,
# Nearest to active: volcanoes, skopje, phishing, mmorpgs, librarianship, disenchanted, australasia, etat,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0296 0.1911 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9710 0.1881 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 3.9986 0.1896 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0784 0.1890 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0351 0.1893 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1254 0.1893 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.0920 0.1888 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 3.9920 0.1890 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.9831 0.1881 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0101 0.1892 sec/batch
# Nearest to four: one, two, zero, nine, seven, three, six, five,
# Nearest to also: hovering, oper, including, tishri, yosef, ceti, kann, photosynthetic,
# Nearest to other: differently, deference, prostaglandin, ultrafilter, rhyming, databases, sterilisation, piper,
# Nearest to is: damping, morphism, ung, of, unachievable, expression, exp, lie,
# Nearest to called: angle, beth, transcendental, almoravids, degrade, circle, familial, philistines,
# Nearest to american: shaughnessy, actor, filenames, nathalie, canadian, race, gelli, sparrows,
# Nearest to seven: six, zero, eight, four, one, nine, five, three,
# Nearest to more: corrupting, bir, coaster, ethnocentric, interceptor, industrial, prepare, bacteriophage,
# Nearest to rise: beholden, uel, hanun, authoritarian, economic, exhibits, unrecognized, abydos,
# Nearest to existence: beasts, idealist, grendel, vernacular, hine, andreini, meaningful, intellectual,
# Nearest to shown: limbo, bathtub, paraphyletic, bagpuss, theatre, carpathian, tuna, bivalent,
# Nearest to http: www, html, com, htm, gov, edu, geocities, asp,
# Nearest to except: identified, shanks, stench, mutagens, coincidentally, oxfam, boredom, praetorian,
# Nearest to pope: ancus, bishop, functioned, severus, viii, popes, xii, moroni,
# Nearest to event: distributism, intruding, astronautica, aloft, untold, mastodon, printout, martin,
# Nearest to active: volcanoes, skopje, phishing, disenchanted, mmorpgs, librarianship, etat, banco,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9733 0.1913 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.9952 0.1891 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 3.9890 0.1886 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 3.9705 0.1881 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0598 0.1888 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0213 0.1742 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9826 0.1892 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9763 0.1915 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9916 0.1902 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9327 0.1889 sec/batch
# Nearest to four: one, two, zero, nine, seven, three, six, five,
# Nearest to also: oper, hovering, yosef, oldest, tishri, maya, ceti, including,
# Nearest to other: prostaglandin, differently, ultrafilter, deference, rhyming, theologically, vocalization, grosseto,
# Nearest to is: damping, morphism, unachievable, of, ung, allahabad, opioid, expression,
# Nearest to called: angle, beth, transcendental, degrade, almoravids, circle, quedlinburg, absence,
# Nearest to american: shaughnessy, actor, nathalie, canadian, filenames, sparrows, gelli, candace,
# Nearest to seven: six, one, eight, zero, four, nine, five, three,
# Nearest to more: corrupting, bir, ethnocentric, coaster, nationhood, bacteriophage, prepare, inclusively,
# Nearest to rise: beholden, hanun, uel, authoritarian, exhibits, unrecognized, abydos, economic,
# Nearest to existence: beasts, idealist, grendel, hine, meaningful, vernacular, apostates, holism,
# Nearest to shown: bathtub, limbo, paraphyletic, theatre, tuna, bagpuss, carpathian, bivalent,
# Nearest to http: www, html, com, htm, gov, geocities, edu, asp,
# Nearest to except: identified, shanks, coincidentally, stench, nether, oxfam, apostolic, boredom,
# Nearest to pope: ancus, severus, popes, bishop, viii, functioned, moroni, papal,
# Nearest to event: distributism, intruding, untold, astronautica, aloft, mastodon, martin, silently,
# Nearest to active: volcanoes, skopje, phishing, mmorpgs, disenchanted, librarianship, highest, liga,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9635 0.1917 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.8931 0.1889 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9994 0.1895 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.9886 0.1889 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9826 0.1887 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9592 0.1882 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8725 0.1883 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9438 0.1879 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.8876 0.1877 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9762 0.1886 sec/batch
# Nearest to four: one, two, zero, nine, seven, three, six, five,
# Nearest to also: hovering, oper, such, including, oldest, yosef, photosynthetic, ceti,
# Nearest to other: prostaglandin, differently, ultrafilter, correspondences, flattened, lagering, schwarzwald, poset,
# Nearest to is: damping, of, morphism, ung, unachievable, a, opioid, therefore,
# Nearest to called: beth, angle, degrade, transcendental, palettes, almoravids, palatable, circle,
# Nearest to american: shaughnessy, filenames, race, sparrows, actor, nathalie, gelli, pants,
# Nearest to seven: six, zero, eight, five, four, one, nine, three,
# Nearest to more: bir, corrupting, ethnocentric, prepare, gradually, nationhood, industrial, bacteriophage,
# Nearest to rise: beholden, uel, hanun, authoritarian, exhibits, economic, abydos, unrecognized,
# Nearest to existence: beasts, grendel, apostates, hine, idealist, meaningful, holism, vernacular,
# Nearest to shown: paraphyletic, bathtub, limbo, tuna, theatre, carpathian, bivalent, kuhn,
# Nearest to http: www, com, html, htm, gov, edu, geocities, asp,
# Nearest to except: identified, praetorian, shanks, oxfam, apostolic, boredom, presides, nether,
# Nearest to pope: ancus, popes, severus, bishop, viii, papal, functioned, boniface,
# Nearest to event: intruding, distributism, untold, astronautica, aloft, printout, martin, nonetheless,
# Nearest to active: volcanoes, skopje, phishing, librarianship, disenchanted, mmorpgs, etat, jedwabne,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9630 0.1913 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9798 0.1883 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9271 0.1889 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9422 0.1887 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0058 0.1905 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9220 0.1894 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9476 0.1886 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9688 0.1891 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9642 0.1888 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9579 0.1892 sec/batch
# Nearest to four: one, two, nine, seven, zero, three, six, five,
# Nearest to also: hovering, oper, including, yosef, such, kaf, photosynthetic, kann,
# Nearest to other: prostaglandin, differently, ultrafilter, methodism, correspondences, schwarzwald, poset, the,
# Nearest to is: damping, of, unachievable, morphism, ung, a, the, realists,
# Nearest to called: beth, angle, transcendental, circle, degrade, toland, entrepreneur, mcghee,
# Nearest to american: shaughnessy, actor, filenames, canadian, nathalie, candace, rosenbloom, actors,
# Nearest to seven: eight, six, one, zero, nine, four, five, three,
# Nearest to more: bir, corrupting, ethnocentric, prepare, much, gradually, atonality, industrial,
# Nearest to rise: uel, beholden, hanun, authoritarian, exhibits, economic, abydos, hebrews,
# Nearest to existence: beasts, grendel, meaningful, idealist, hine, apostates, holism, that,
# Nearest to shown: paraphyletic, bathtub, limbo, theatre, bagpuss, tuna, hardness, carpathian,
# Nearest to http: www, html, com, htm, gov, edu, geocities, asp,
# Nearest to except: identified, praetorian, oxfam, apostolic, presides, shanks, coincidentally, boredom,
# Nearest to pope: ancus, popes, papal, bishop, functioned, severus, viii, boniface,
# Nearest to event: intruding, distributism, printout, aloft, astronautica, nonetheless, show, quirks,
# Nearest to active: volcanoes, skopje, phishing, librarianship, mmorpgs, disenchanted, recreational, liga,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9459 0.1917 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9415 0.1890 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9442 0.1890 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9518 0.1890 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9902 0.1887 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9825 0.1886 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9460 0.1890 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9267 0.1886 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9397 0.1888 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0142 0.1888 sec/batch
# Nearest to four: one, two, nine, zero, seven, three, six, five,
# Nearest to also: hovering, oper, including, such, maya, groupoid, photosynthetic, a,
# Nearest to other: differently, prostaglandin, methodism, the, deference, wide, and, theologically,
# Nearest to is: damping, of, morphism, allahabad, ung, groups, a, therefore,
# Nearest to called: beth, angle, transcendental, almoravids, degrade, circle, quedlinburg, absence,
# Nearest to american: shaughnessy, actor, canadian, filenames, candace, nathalie, actors, gelli,
# Nearest to seven: eight, one, six, nine, zero, four, five, three,
# Nearest to more: bir, corrupting, industrial, ethnocentric, much, prepare, significant, housemates,
# Nearest to rise: uel, beholden, hanun, authoritarian, economic, exhibits, abydos, broader,
# Nearest to existence: beasts, grendel, meaningful, idealist, apostates, hine, andreini, sothoth,
# Nearest to shown: paraphyletic, bathtub, limbo, bagpuss, hardness, theatre, carpathian, tuna,
# Nearest to http: www, html, com, htm, gov, geocities, edu, asp,
# Nearest to except: identified, shanks, presides, oxfam, apostolic, echoing, boredom, coincidentally,
# Nearest to pope: ancus, papal, bishop, popes, functioned, viii, severus, boniface,
# Nearest to event: distributism, intruding, aloft, martin, astronautica, printout, interleave, untold,
# Nearest to active: volcanoes, skopje, phishing, librarianship, highest, mmorpgs, recreational, disenchanted,
# ...
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.7073 0.1878 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.7961 0.1877 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7475 0.1879 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.7248 0.1881 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.7858 0.1882 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8141 0.1882 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.7829 0.1887 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.7989 0.1881 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8537 0.1886 sec/batch
# Nearest to four: one, two, three, nine, five, seven, zero, six,
# Nearest to also: as, and, the, of, including, on, a, hovering,
# Nearest to other: and, the, of, such, some, which, also, to,
# Nearest to is: of, a, the, in, as, it, for, both,
# Nearest to called: angle, toland, palettes, with, the, is, ino, arrive,
# Nearest to american: canadian, rosenbloom, multiracial, francks, actors, english, abo, volleyball,
# Nearest to seven: one, eight, six, nine, five, four, three, two,
# Nearest to more: most, atonality, corrupting, much, and, some, have, sushi,
# Nearest to rise: beholden, authoritarian, uel, economic, hanun, thirties, cosmopolitanism, broader,
# Nearest to existence: that, buying, creatures, grendel, orientalis, litovsk, andreini, sothoth,
# Nearest to shown: bivalent, paraphyletic, theatre, bagpuss, ntsc, erdrich, sag, bathtub,
# Nearest to http: www, htm, html, com, edu, geocities, gov, org,
# Nearest to except: presides, identified, teeming, shanks, apostolic, lfr, even, stench,
# Nearest to pope: papal, boniface, popes, xii, antipope, ancus, reconciliation, severus,
# Nearest to event: show, intruding, olympics, printout, martin, interleave, untold, environmental,
# Nearest to active: volcanoes, deoxygenated, skopje, highest, phishing, jedwabne, librarianship, honors,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.7963 0.1916 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.7893 0.1898 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8037 0.1884 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8123 0.1884 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.7963 0.1882 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8137 0.1886 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8355 0.1884 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.7994 0.1887 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8281 0.1882 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8013 0.1887 sec/batch
# Nearest to four: one, two, three, nine, seven, five, zero, six,
# Nearest to also: the, as, and, of, a, is, on, including,
# Nearest to other: and, of, the, which, some, are, such, also,
# Nearest to is: of, a, the, as, in, also, it, for,
# Nearest to called: angle, toland, is, and, palettes, ino, known, palatable,
# Nearest to american: canadian, actors, rosenbloom, francks, multiracial, identifies, volleyball, abo,
# Nearest to seven: one, six, eight, nine, five, two, three, four,
# Nearest to more: most, atonality, much, plurality, and, corrupting, than, sushi,
# Nearest to rise: beholden, economic, uel, authoritarian, dramatically, thirties, broader, hermannus,
# Nearest to existence: that, orientalis, grendel, creatures, buying, andreini, universe, sothoth,
# Nearest to shown: bivalent, paraphyletic, bagpuss, theatre, erdrich, sag, louise, ntsc,
# Nearest to http: www, htm, html, com, edu, geocities, gov, org,
# Nearest to except: presides, identified, apostolic, lfr, teeming, shanks, unwilling, praetorian,
# Nearest to pope: papal, xii, popes, antipope, ancus, boniface, reconciliation, mw,
# Nearest to event: intruding, olympics, show, martin, printout, greenpeace, untold, given,
# Nearest to active: volcanoes, deoxygenated, skopje, highest, nonsignatory, phishing, honors, librarianship,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8225 0.1915 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8109 0.1888 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.7911 0.1882 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.7473 0.1887 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8638 0.1884 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8229 0.1884 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9374 0.1892 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8382 0.1895 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8627 0.1893 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.7604 0.1879 sec/batch
# Nearest to four: one, two, three, nine, five, seven, zero, six,
# Nearest to also: the, as, of, and, a, on, is, including,
# Nearest to other: and, of, the, such, also, to, some, are,
# Nearest to is: of, a, the, in, as, also, for, part,
# Nearest to called: angle, is, toland, ino, and, palatable, palettes, aniston,
# Nearest to american: canadian, actors, actor, francks, rosenbloom, multiracial, volleyball, tzen,
# Nearest to seven: one, six, eight, nine, five, three, two, four,
# Nearest to more: and, atonality, most, of, much, sushi, plurality, popular,
# Nearest to rise: beholden, economic, uel, authoritarian, cosmopolitanism, thirties, dramatically, hanun,
# Nearest to existence: buying, orientalis, grendel, that, litovsk, andreini, yong, universe,
# Nearest to shown: bivalent, paraphyletic, theatre, bagpuss, erdrich, louise, sag, ntsc,
# Nearest to http: www, htm, html, com, edu, gov, geocities, org,
# Nearest to except: presides, identified, lfr, teeming, shanks, apostolic, stench, echoing,
# Nearest to pope: papal, xii, antipope, popes, boniface, mw, ancus, reconciliation,
# Nearest to event: olympics, martin, intruding, show, given, greenpeace, untold, printout,
# Nearest to active: volcanoes, skopje, deoxygenated, nonsignatory, highest, league, phishing, khmelnytsky,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7223 0.1907 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8406 0.1890 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7342 0.1888 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8190 0.1883 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.7709 0.1883 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8392 0.1886 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8593 0.1075 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8023 0.1883 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8193 0.1885 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8086 0.1888 sec/batch
# Nearest to four: one, two, three, five, seven, nine, zero, six,
# Nearest to also: as, and, the, of, a, is, other, on,
# Nearest to other: and, of, the, such, many, also, which, there,
# Nearest to is: of, a, the, in, as, it, part, also,
# Nearest to called: angle, toland, and, is, ino, known, specifying, palettes,
# Nearest to american: canadian, actor, english, francks, rosenbloom, frank, actors, british,
# Nearest to seven: one, eight, six, five, nine, three, two, four,
# Nearest to more: most, corrupting, atonality, than, such, plurality, and, structured,
# Nearest to rise: beholden, economic, uel, authoritarian, thirties, broader, hanun, cosmopolitanism,
# Nearest to existence: orientalis, that, shaivism, buying, sothoth, litovsk, grendel, cannot,
# Nearest to shown: bivalent, paraphyletic, theatre, bagpuss, erdrich, shows, been, igd,
# Nearest to http: www, htm, com, html, edu, geocities, gov, org,
# Nearest to except: presides, lfr, identified, teeming, apostolic, shanks, praetorian, testaments,
# Nearest to pope: papal, xii, antipope, popes, ancus, boniface, mw, keh,
# Nearest to event: intruding, olympics, martin, untold, show, greenpeace, recycled, environmental,
# Nearest to active: volcanoes, skopje, highest, deoxygenated, nonsignatory, league, jedwabne, khmelnytsky,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.7634 0.1918 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.7887 0.1882 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7651 0.1886 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7490 0.1890 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8296 0.1882 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.7929 0.1885 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8143 0.1880 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7146 0.1880 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7599 0.1890 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7369 0.1873 sec/batch
# Nearest to four: one, two, three, five, seven, nine, zero, six,
# Nearest to also: the, as, and, of, a, in, is, other,
# Nearest to other: and, of, the, such, also, some, to, many,
# Nearest to is: of, a, in, the, as, for, also, it,
# Nearest to called: and, is, angle, toland, known, an, the, with,
# Nearest to american: canadian, francks, actors, rosenbloom, multiracial, volleyball, wanton, torontonians,
# Nearest to seven: one, eight, six, five, nine, four, three, two,
# Nearest to more: and, most, than, of, such, atonality, much, the,
# Nearest to rise: beholden, economic, uel, authoritarian, pyrenean, hermannus, thirties, broader,
# Nearest to existence: orientalis, that, buying, cannot, litovsk, yong, shaivism, universe,
# Nearest to shown: bivalent, paraphyletic, theatre, bagpuss, erdrich, be, sag, shows,
# Nearest to http: www, htm, html, com, edu, geocities, gov, org,
# Nearest to except: presides, identified, lfr, teeming, praetorian, prefer, apostolic, baronies,
# Nearest to pope: papal, popes, xii, antipope, mw, boniface, survive, ancus,
# Nearest to event: olympics, greenpeace, environmental, intruding, untold, show, martin, interleave,
# Nearest to active: volcanoes, skopje, deoxygenated, highest, nonsignatory, jedwabne, phishing, librarianship,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.6803 0.1908 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.7800 0.1888 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8118 0.1883 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.7961 0.1879 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.7607 0.1887 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8596 0.1891 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.7859 0.1887 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.7623 0.1972 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.7740 0.2067 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8073 0.2022 sec/batch
# Nearest to four: one, two, three, nine, five, seven, zero, six,
# Nearest to also: as, the, of, and, a, is, on, including,
# Nearest to other: and, of, the, such, some, also, to, which,
# Nearest to is: of, a, the, in, as, for, also, it,
# Nearest to called: is, and, toland, known, an, angle, the, palatable,
# Nearest to american: canadian, francks, actors, rosenbloom, multiracial, frank, actor, songwriters,
# Nearest to seven: one, eight, six, nine, five, four, three, two,
# Nearest to more: much, atonality, and, than, of, such, most, sushi,
# Nearest to rise: beholden, uel, economic, thirties, pyrenean, gave, hermannus, polytechnique,
# Nearest to existence: orientalis, that, cannot, buying, yong, litovsk, andreini, shaivism,
# Nearest to shown: bivalent, paraphyletic, theatre, erdrich, bagpuss, sag, marduk, been,
# Nearest to http: www, htm, com, html, edu, org, geocities, gov,
# Nearest to except: presides, lfr, apostolic, identified, prefer, praetorian, teeming, unwilling,
# Nearest to pope: papal, xii, popes, antipope, boniface, mw, survive, reconciliation,
# Nearest to event: olympics, intruding, greenpeace, environmental, show, aloft, martin, events,
# Nearest to active: volcanoes, deoxygenated, skopje, highest, nonsignatory, jedwabne, phishing, honors,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8297 0.2046 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.7916 0.2023 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.7799 0.2016 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.7510 0.2024 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.7998 0.2025 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8063 0.2022 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.7721 0.2019 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8029 0.2016 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7490 0.2011 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7425 0.2015 sec/batch
# Nearest to four: one, two, three, five, nine, seven, zero, six,
# Nearest to also: and, as, the, of, is, a, in, on,
# Nearest to other: and, of, the, such, also, are, some, which,
# Nearest to is: a, of, the, also, as, in, for, are,
# Nearest to called: is, and, toland, an, the, known, angle, a,
# Nearest to american: canadian, francks, actors, identifies, multiracial, torontonians, rosenbloom, recipients,
# Nearest to seven: one, eight, six, nine, five, four, three, two,
# Nearest to more: and, of, much, than, often, the, such, are,
# Nearest to rise: beholden, economic, hermannus, uel, broader, pyrenean, cosmopolitanism, polytechnique,
# Nearest to existence: orientalis, buying, cannot, that, litovsk, andreini, shaivism, sothoth,
# Nearest to shown: bivalent, paraphyletic, sag, erdrich, theatre, shows, ntsc, exopterygota,
# Nearest to http: www, htm, com, html, edu, org, geocities, gov,
# Nearest to except: presides, lfr, prefer, apostolic, teeming, even, unwilling, identified,
# Nearest to pope: papal, popes, xii, antipope, reconciliation, mw, survive, boniface,
# Nearest to event: olympics, greenpeace, show, environmental, intruding, aloft, untold, events,
# Nearest to active: volcanoes, skopje, deoxygenated, highest, nonsignatory, jedwabne, metabolically, phishing,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8011 0.2038 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8172 0.2012 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.8555 0.2016 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8979 0.2102 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8136 0.1894 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8043 0.1889 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7126 0.1890 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.7861 0.1879 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.6916 0.1878 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8245 0.1883 sec/batch
# Nearest to four: one, two, three, five, seven, nine, zero, six,
# Nearest to also: of, as, and, the, is, other, a, in,
# Nearest to other: and, of, the, such, are, which, also, to,
# Nearest to is: a, of, the, in, also, as, it, for,
# Nearest to called: is, and, angle, an, toland, palatable, known, the,
# Nearest to american: english, canadian, francks, actors, frank, actor, songwriters, rosenbloom,
# Nearest to seven: one, eight, six, nine, five, four, three, two,
# Nearest to more: and, of, often, than, such, a, much, are,
# Nearest to rise: beholden, economic, hermannus, uel, broader, cosmopolitanism, pyrenean, thirties,
# Nearest to existence: orientalis, buying, cannot, litovsk, that, sothoth, shaivism, andreini,
# Nearest to shown: bivalent, paraphyletic, erdrich, shows, sag, bagpuss, be, theatre,
# Nearest to http: www, htm, html, com, edu, geocities, org, gov,
# Nearest to except: lfr, presides, prefer, teeming, identified, nitrides, testaments, unwilling,
# Nearest to pope: papal, popes, xii, antipope, mw, reconciliation, survive, boniface,
# Nearest to event: olympics, greenpeace, show, untold, environmental, intruding, events, aloft,
# Nearest to active: volcanoes, skopje, nonsignatory, deoxygenated, highest, khmelnytsky, librarianship, surprise,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.7851 0.1911 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.7653 0.1884 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
